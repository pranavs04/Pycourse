# %%
import pandas as pd 
# importing the data
log_data = pd.read_csv('C:\\Users\\PRANAV SAXENA\\Desktop\\Python\\basic_course-master\\Lecture_3\\data\\log_data_csv.csv')
log_data
# Out:
#         DEPTH  ABDCQF01  ABDCQF02  ABDCQF03  ABDCQF04    BS  CALI  DRHO  DT  \
# 0       145.9       NaN       NaN       NaN       NaN  36.0   NaN   NaN NaN
# 1       146.0       NaN       NaN       NaN       NaN  36.0   NaN   NaN NaN
# 2       146.1       NaN       NaN       NaN       NaN  36.0   NaN   NaN NaN
# 3       146.2       NaN       NaN       NaN       NaN  36.0   NaN   NaN NaN
# 4       146.3       NaN       NaN       NaN       NaN  36.0   NaN   NaN NaN
# ...       ...       ...       ...       ...       ...   ...   ...   ...  ..
# 33186  3464.5       NaN       NaN       NaN       NaN   8.5   NaN   NaN NaN
# 33187  3464.6       NaN       NaN       NaN       NaN   8.5   NaN   NaN NaN
# 33188  3464.7       NaN       NaN       NaN       NaN   8.5   NaN   NaN NaN
# 33189  3464.8       NaN       NaN       NaN       NaN   8.5   NaN   NaN NaN
# 33190  3464.9       NaN       NaN       NaN       NaN   8.5   NaN   NaN NaN
#
#        DTS  ...  PEF  RACEHM  RACELM  RD  RHOB  RM      ROP  RPCEHM  RPCELM  \
# 0      NaN  ...  NaN     NaN     NaN NaN   NaN NaN      NaN     NaN     NaN
# 1      NaN  ...  NaN     NaN     NaN NaN   NaN NaN      NaN     NaN     NaN
# 2      NaN  ...  NaN     NaN     NaN NaN   NaN NaN      NaN     NaN     NaN
# 3      NaN  ...  NaN     NaN     NaN NaN   NaN NaN      NaN     NaN     NaN
# 4      NaN  ...  NaN     NaN     NaN NaN   NaN NaN      NaN     NaN     NaN
# ...    ...  ...  ...     ...     ...  ..   ...  ..      ...     ...     ...
# 33186  NaN  ...  NaN     NaN     NaN NaN   NaN NaN  29.9836     NaN     NaN
# 33187  NaN  ...  NaN     NaN     NaN NaN   NaN NaN  29.9767     NaN     NaN
# 33188  NaN  ...  NaN     NaN     NaN NaN   NaN NaN  29.9699     NaN     NaN
# 33189  NaN  ...  NaN     NaN     NaN NaN   NaN NaN  29.9903     NaN     NaN
# 33190  NaN  ...  NaN     NaN     NaN NaN   NaN NaN      NaN     NaN     NaN
#
#        RT
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ...    ..
# 33186 NaN
# 33187 NaN
# 33188 NaN
# 33189 NaN
# 33190 NaN
#
# [33191 rows x 23 columns]

# %%
# E1
import matplotlib.pyplot as plt # importing the library
plt.figure(figsize=(10,12))      # determining the figure size
plt.title('NPHI vs DEPTH', fontsize=18) # assigning plot title
plt.xlabel('NPHI', fontsize=12)  # assigning x-axis title
plt.ylabel('DEPTH', fontsize=12) # assigning y-axis title
plt.scatter(x=log_data['NPHI'], y=log_data['DEPTH'], c= log_data['GR']) # plotting the graph with Neutron porosity on x and depth on y axis and adding color refering to GR
plt.gca().invert_yaxis() # inverting the y-axis
GR_colorbar=plt.colorbar() # adding colorbar for reference
GR_colorbar.ax.set_title('Gamma Ray') # assigning colorbar title
# Out:
# Text(0.5, 1.0, 'Gamma Ray')

# %%
# E2
import numpy as np
log_data['LITHOLOGY'] = np.where(log_data.GR>=75, 'SHALE', 'SANDSTONE')
log_data
# Out:
#         DEPTH  ABDCQF01  ABDCQF02  ABDCQF03  ABDCQF04    BS  CALI  DRHO  DT  \
# 0       145.9       NaN       NaN       NaN       NaN  36.0   NaN   NaN NaN
# 1       146.0       NaN       NaN       NaN       NaN  36.0   NaN   NaN NaN
# 2       146.1       NaN       NaN       NaN       NaN  36.0   NaN   NaN NaN
# 3       146.2       NaN       NaN       NaN       NaN  36.0   NaN   NaN NaN
# 4       146.3       NaN       NaN       NaN       NaN  36.0   NaN   NaN NaN
# ...       ...       ...       ...       ...       ...   ...   ...   ...  ..
# 33186  3464.5       NaN       NaN       NaN       NaN   8.5   NaN   NaN NaN
# 33187  3464.6       NaN       NaN       NaN       NaN   8.5   NaN   NaN NaN
# 33188  3464.7       NaN       NaN       NaN       NaN   8.5   NaN   NaN NaN
# 33189  3464.8       NaN       NaN       NaN       NaN   8.5   NaN   NaN NaN
# 33190  3464.9       NaN       NaN       NaN       NaN   8.5   NaN   NaN NaN
#
#        DTS  ...  RACEHM  RACELM  RD  RHOB  RM      ROP  RPCEHM  RPCELM  RT  \
# 0      NaN  ...     NaN     NaN NaN   NaN NaN      NaN     NaN     NaN NaN
# 1      NaN  ...     NaN     NaN NaN   NaN NaN      NaN     NaN     NaN NaN
# 2      NaN  ...     NaN     NaN NaN   NaN NaN      NaN     NaN     NaN NaN
# 3      NaN  ...     NaN     NaN NaN   NaN NaN      NaN     NaN     NaN NaN
# 4      NaN  ...     NaN     NaN NaN   NaN NaN      NaN     NaN     NaN NaN
# ...    ...  ...     ...     ...  ..   ...  ..      ...     ...     ...  ..
# 33186  NaN  ...     NaN     NaN NaN   NaN NaN  29.9836     NaN     NaN NaN
# 33187  NaN  ...     NaN     NaN NaN   NaN NaN  29.9767     NaN     NaN NaN
# 33188  NaN  ...     NaN     NaN NaN   NaN NaN  29.9699     NaN     NaN NaN
# 33189  NaN  ...     NaN     NaN NaN   NaN NaN  29.9903     NaN     NaN NaN
# 33190  NaN  ...     NaN     NaN NaN   NaN NaN      NaN     NaN     NaN NaN
#
#        LITHOLOGY
# 0      SANDSTONE
# 1      SANDSTONE
# 2      SANDSTONE
# 3      SANDSTONE
# 4      SANDSTONE
# ...          ...
# 33186  SANDSTONE
# 33187  SANDSTONE
# 33188  SANDSTONE
# 33189  SANDSTONE
# 33190  SANDSTONE
#
# [33191 rows x 24 columns]

# %%
# E2
import matplotlib.pyplot as plt # importing the library
# determining the figure size
plt.title('NPHI vs RHOB', fontsize=18) # assigning plot title
plt.xlabel('NPHI', fontsize=12)  # assigning x-axis title
plt.ylabel('RHOB', fontsize=12) # assigning y-axis title
color = ['red' if i=='SHALE'  else 'blue' for i in log_data['LITHOLOGY']]
plt.scatter(x=log_data['NPHI'], y=log_data['RHOB'], c= color) # plotting the graph with Neutron porosity on x and depth on y axis and adding color refering to GR

# %%
# E3
import seaborn as sns
sns.catplot(x='LITHOLOGY', y='GR', data=log_data)
sns.catplot(x='LITHOLOGY', y='RHOB', data=log_data)

# Combining both, GR and RHOB with Lithology. Following code shows GR and RHOB on a single plot with Lithology on x-axis
#ax1 = plt.subplots(figsize=(10,6))
#ax1 = sns.barplot(x='LITHOLOGY',y='GR', data=log_data)
#ax1.tick_params(axis='y')
#ax2 = ax1.twinx()
#ax2=sns.lineplot(x='LITHOLOGY', y='RHOB', data=log_data, sort=False)
#ax2.tick_params(axis='y')

# %%
sns.catplot(x='LITHOLOGY', y='GR', data=log_data, kind='box')
sns.catplot(x='LITHOLOGY', y='RHOB', data=log_data, kind='box')

# %%
# E5
#import plotly.graph_objects as go
#go.Figure(data=go.Histogram(x=log_data['LITHOLOGY'], y=))
#fig = go.Figure(layout=go.Layout(title=go.layout.Title(text="Histogram of ROP Log based on different lithologies"),
#                xaxis=dict(title="ROP Values"),
#                #yaxis=dict(title="Depth", range=[0, 0.4]),
 #               width = 800,
  #              height = 800))

#for lithology_value in log_data['LITHOLOGY'].unique():
 #   
  #  fig.add_trace(go.Histogram(x=log_data['ROP'][log_data['LITHOLOGY'] == lithology_value],name = lithology_value, xbins=dict(size=20))) 

#fig.show()
import plotly.express as px
fig = px.histogram(log_data, x="ROP", y="DEPTH", color="LITHOLOGY")
fig.show()
# Out:
# <div>
#
#
#             <div id="3be3f27a-f237-4718-ae45-e3f42b0f3e4c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3be3f27a-f237-4718-ae45-e3f42b0f3e4c")) {
#                     Plotly.newPlot(
#                         '3be3f27a-f237-4718-ae45-e3f42b0f3e4c',
#                         [{"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "LITHOLOGY=SANDSTONE<br>ROP=%{x}<br>sum of DEPTH=%{y}<extra></extra>", "legendgroup": "SANDSTONE", "marker": {"color": "#636efa"}, "name": "SANDSTONE", "offsetgroup": "SANDSTONE", "orientation": "v", "showlegend": true, "type": "histogram", "x": [null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null,  ...
